# %%
import requests
from time import sleep
from tqdm import tqdm
import random

# %%
headers = {
    'Authorization': '', #https://onecall.no/mobilabonnement/bestill/folkepakka-0-gb-q
}

# %%
def get_available_numbers(n):
    unique_numbers = set()
    
    pbar = tqdm(total=n)
    
    while True:
        r = requests.get('https://ocapi.onecall.no/orderflow/numbers?maxcount=100&type=gold',
                         headers=headers)
        
        if r.status_code != 200:
            return
        
        numbers = r.json()['numbers']
        pbar.update(len(set(numbers).difference(unique_numbers)))
        unique_numbers.update(numbers)
        
        sleep(random.uniform(1.0, 2.0))
        
        if len(unique_numbers) >= n:
            pbar.close()
            return random.sample(unique_numbers, n)

# %%
numbers = get_available_numbers(100)
# Out:
# 108it [00:27,  3.95it/s]

# %%
with open('numbers.txt', 'w') as file:
    file.write(', '.join(numbers))

# %%
from collections import Counter
import re

print(f'Received {len(numbers)} numbers')
for n in sorted(numbers):
    one_letter = Counter(str(n)).most_common()
    n_letters = [m.group() for m in re.finditer(r'(?:(\w)\1+){1}', str(n))]
    print(f'{n}, {one_letter[:3]}, {n_letters}')
# Out:
# Received 100 numbers
# 40533354, [('3', 3), ('4', 2), ('5', 2)], ['333']
# 40534564, [('4', 3), ('5', 2), ('0', 1)], []
# 40543218, [('4', 2), ('0', 1), ('5', 1)], []
# 46777329, [('7', 3), ('4', 1), ('6', 1)], ['777']
# 46779550, [('7', 2), ('5', 2), ('4', 1)], ['77', '55']
# 46799924, [('9', 3), ('4', 2), ('6', 1)], ['999']
# 48444907, [('4', 4), ('8', 1), ('9', 1)], ['444']
# 48450099, [('4', 2), ('0', 2), ('9', 2)], ['00', '99']
# 48466638, [('6', 3), ('4', 2), ('8', 2)], ['666']
# 48466647, [('4', 3), ('6', 3), ('8', 1)], ['666']
# 92111279, [('1', 3), ('9', 2), ('2', 2)], ['111']
# 92111406, [('1', 3), ('9', 1), ('2', 1)], ['111']
# 92111495, [('1', 3), ('9', 2), ('2', 1)], ['111']
# 92111648, [('1', 3), ('9', 1), ('2', 1)], ['111']
# 92111769, [('1', 3), ('9', 2), ('2', 1)], ['111']
# 92111901, [('1', 4), ('9', 2), ('2', 1)], ['111']
# 92112348, [('2', 2), ('1', 2), ('9', 1)], ['11']
# 92112377, [('2', 2), ('1', 2), ('7', 2)], ['11', '77']
# 92112380, [('2', 2), ('1', 2), ('9', 1)], ['11']
# 92112398, [('9', 2), ('2', 2), ('1', 2)], ['11']
# 92123600, [('2', 2), ('0', 2), ('9', 1)], ['00']
# 92125777, [('7', 3), ('2', 2), ('9', 1)], ['777']
# 92126661, [('6', 3), ('2', 2), ('1', 2)], ['666']
# 92127771, [('7', 3), ('2', 2), ('1', 2)], ['777']
# 92130040, [('0', 3), ('9', 1), ('2', 1)], ['00']
# 92130080, [('0', 3), ('9', 1), ('2', 1)], ['00']
# 92131888, [('8', 3), ('1', 2), ('9', 1)], ['888']
# 92133009, [('9', 2), ('3', 2), ('0', 2)], ['33', '00']
# 92133348, [('3', 3), ('9', 1), ('2', 1)], ['333']
# 92133375, [('3', 3), ('9', 1), ('2', 1)], ['333']
# 92133381, [('3', 3), ('1', 2), ('9', 1)], ['333']
# 92133387, [('3', 3), ('9', 1), ('2', 1)], ['333']
# 92133388, [('3', 3), ('8', 2), ('9', 1)], ['333', '88']
# 92133391, [('3', 3), ('9', 2), ('1', 2)], ['333']
# 92133395, [('3', 3), ('9', 2), ('2', 1)], ['333']
# 92133396, [('3', 3), ('9', 2), ('2', 1)], ['333']
# 92136444, [('4', 3), ('9', 1), ('2', 1)], ['444']
# 92138885, [('8', 3), ('9', 1), ('2', 1)], ['888']
# 92138886, [('8', 3), ('9', 1), ('2', 1)], ['888']
# 92141999, [('9', 4), ('1', 2), ('2', 1)], ['999']
# 92143555, [('5', 3), ('9', 1), ('2', 1)], ['555']
# 92144009, [('9', 2), ('4', 2), ('0', 2)], ['44', '00']
# 92144456, [('4', 3), ('9', 1), ('2', 1)], ['444']
# 92145559, [('5', 3), ('9', 2), ('2', 1)], ['555']
# 92149888, [('8', 3), ('9', 2), ('2', 1)], ['888']
# 92150006, [('0', 3), ('9', 1), ('2', 1)], ['000']
# 92150010, [('0', 3), ('1', 2), ('9', 1)], ['00']
# 92150333, [('3', 3), ('9', 1), ('2', 1)], ['333']
# 92151113, [('1', 4), ('9', 1), ('2', 1)], ['111']
# 92154300, [('0', 2), ('9', 1), ('2', 1)], ['00']
# 92155007, [('5', 2), ('0', 2), ('9', 1)], ['55', '00']
# 92155504, [('5', 3), ('9', 1), ('2', 1)], ['555']
# 92155567, [('5', 3), ('9', 1), ('2', 1)], ['555']
# 92155582, [('5', 3), ('2', 2), ('9', 1)], ['555']
# 92157772, [('7', 3), ('2', 2), ('9', 1)], ['777']
# 92160033, [('0', 2), ('3', 2), ('9', 1)], ['00', '33']
# 92160444, [('4', 3), ('9', 1), ('2', 1)], ['444']
# 92163332, [('3', 3), ('2', 2), ('9', 1)], ['333']
# 92165777, [('7', 3), ('9', 1), ('2', 1)], ['777']
# 92166004, [('6', 2), ('0', 2), ('9', 1)], ['66', '00']
# 92166607, [('6', 3), ('9', 1), ('2', 1)], ['666']
# 92166610, [('6', 3), ('1', 2), ('9', 1)], ['666']
# 92166679, [('6', 3), ('9', 2), ('2', 1)], ['666']
# 92167770, [('7', 3), ('9', 1), ('2', 1)], ['777']
# 92167771, [('7', 3), ('1', 2), ('9', 1)], ['777']
# 92312666, [('6', 3), ('2', 2), ('9', 1)], ['666']
# 92315550, [('5', 3), ('9', 1), ('2', 1)], ['555']
# 92316111, [('1', 4), ('9', 1), ('2', 1)], ['111']
# 92316663, [('6', 3), ('3', 2), ('9', 1)], ['666']
# 92316665, [('6', 3), ('9', 1), ('2', 1)], ['666']
# 92321919, [('9', 3), ('2', 2), ('1', 2)], []
# 92329111, [('1', 3), ('9', 2), ('2', 2)], ['111']
# 92330057, [('3', 2), ('0', 2), ('9', 1)], ['33', '00']
# 92333560, [('3', 3), ('9', 1), ('2', 1)], ['333']
# 92333566, [('3', 3), ('6', 2), ('9', 1)], ['333', '66']
# 92333595, [('3', 3), ('9', 2), ('5', 2)], ['333']
# 92333853, [('3', 4), ('9', 1), ('2', 1)], ['333']
# 92333981, [('3', 3), ('9', 2), ('2', 1)], ['333']
# 92334008, [('3', 2), ('0', 2), ('9', 1)], ['33', '00']
# 92340025, [('2', 2), ('0', 2), ('9', 1)], ['00']
# 92340061, [('0', 2), ('9', 1), ('2', 1)], ['00']
# 92341002, [('2', 2), ('0', 2), ('9', 1)], ['00']
# 92341114, [('1', 3), ('4', 2), ('9', 1)], ['111']
# 92341700, [('0', 2), ('9', 1), ('2', 1)], ['00']
# 92343006, [('3', 2), ('0', 2), ('9', 1)], ['00']
# 92343007, [('3', 2), ('0', 2), ('9', 1)], ['00']
# 92343338, [('3', 4), ('9', 1), ('2', 1)], ['333']
# 92344435, [('4', 3), ('3', 2), ('9', 1)], ['444']
# 92344555, [('5', 3), ('4', 2), ('9', 1)], ['44', '555']
# 92344600, [('4', 2), ('0', 2), ('9', 1)], ['44', '00']
# 92345659, [('9', 2), ('5', 2), ('2', 1)], []
# 92345663, [('3', 2), ('6', 2), ('9', 1)], ['66']
# 92345669, [('9', 2), ('6', 2), ('2', 1)], ['66']
# 92345681, [('9', 1), ('2', 1), ('3', 1)], []
# 92346777, [('7', 3), ('9', 1), ('2', 1)], ['777']
# 92348666, [('6', 3), ('9', 1), ('2', 1)], ['666']
# 92348800, [('8', 2), ('0', 2), ('9', 1)], ['88', '00']
# 92349991, [('9', 4), ('2', 1), ('3', 1)], ['999']
# 92352224, [('2', 4), ('9', 1), ('3', 1)], ['222']
# 92358882, [('8', 3), ('2', 2), ('9', 1)], ['888']
